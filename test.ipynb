# %%
import os
import numpy as np
from scraper.data_loader import DataLoader
from grid_manager import GridManager

# %%
city_test_name = "Kraków"
filename = "krakow_test.grid"
data_dir = "grids"

# %%
file_path = os.path.join(data_dir, filename)
if os.path.exists(file_path):
    os.remove(file_path)
    print(f"Usunięto stary plik: {filename}")
# Out:
# Usunięto stary plik: krakow_test.grid

# %%
loader = DataLoader(grid_density=1.0, segment_h=1000, segment_w=1000, data_dir=data_dir)

# %%
grid_manager = loader.load_city_grid(city_test_name, filename)
# Out:
# Roads with 'width' attribute: 65721
# Roads without 'width' attribute: 93810
# Width: 29682, height: 17017, cols: 18, rows: 30
# Segment: 0, 0
# Grid segment shape: (1000, 1000)
# Segment: 0, 1
# Grid segment shape: (1000, 1000)
# Segment: 0, 2
# Grid segment shape: (1000, 1000)
# Segment: 0, 3
# Grid segment shape: (1000, 1000)
# Segment: 0, 4
# Grid segment shape: (1000, 1000)
# Segment: 0, 5
# Grid segment shape: (1000, 1000)
# Segment: 0, 6
# Grid segment shape: (1000, 1000)
# Segment: 0, 7
# Grid segment shape: (1000, 1000)
# Segment: 0, 8
# Grid segment shape: (1000, 1000)
# Segment: 0, 9
# Grid segment shape: (1000, 1000)
# Segment: 0, 10
# Grid segment shape: (1000, 1000)
# Segment: 0, 11
# Grid segment shape: (1000, 1000)
# Segment: 0, 12
# Grid segment shape: (1000, 1000)
# Segment: 0, 13
# Grid segment shape: (1000, 1000)
# Segment: 0, 14
# Grid segment shape: (1000, 1000)
# Segment: 0, 15
# Grid segment shape: (1000, 1000)
# Segment: 0, 16
# Grid segment shape: (1000, 1000)
# Segment: 0, 17
# Grid segment shape: (1000, 17)
# Segment: 1, 0
# Grid segment shape: (1000, 1000)
# Segment: 1, 1
# Grid segment shape: (1000, 1000)
# Segment: 1, 2
# Grid segment shape: (1000, 1000)
# Segment: 1, 3
# Grid segment shape: (1000, 1000)
# Segment: 1, 4
# Grid segment shape: (1000, 1000)
# Segment: 1, 5
# Grid segment shape: (1000, 1000)
# Segment: 1, 6
# Grid segment shape: (1000, 1000)
# Segment: 1, 7
# Grid segment shape: (1000, 1000)
# Segment: 1, 8
# Grid segment shape: (1000, 1000)
# Segment: 1, 9
# Grid segment shape: (1000, 1000)
# Segment: 1, 10
# Grid segment shape: (1000, 1000)
# Segment: 1, 11
# Grid segment shape: (1000, 1000)
# Segment: 1, 12
# Grid segment shape: (1000, 1000)
# Segment: 1, 13
# Grid segment shape: (1000, 1000)
# Segment: 1, 14
# Grid segment shape: (1000, 1000)
# Segment: 1, 15
# Grid segment shape: (1000, 1000)
# Segment: 1, 16
# Grid segment shape: (1000, 1000)
# Segment: 1, 17
# Grid segment shape: (1000, 17)
# Segment: 2, 0
# Grid segment shape: (1000, 1000)
# Segment: 2, 1
# Grid segment shape: (1000, 1000)
# Segment: 2, 2
# Grid segment shape: (1000, 1000)
# Segment: 2, 3
# Grid segment shape: (1000, 1000)
# Segment: 2, 4
# Grid segment shape: (1000, 1000)
# Segment: 2, 5
# Grid segment shape: (1000, 1000)
# Segment: 2, 6
# Grid segment shape: (1000, 1000)
# Segment: 2, 7
# Grid segment shape: (1000, 1000)
# Segment: 2, 8
# Grid segment shape: (1000, 1000)
# Segment: 2, 9
# Grid segment shape: (1000, 1000)
# Segment: 2, 10
# Grid segment shape: (1000, 1000)
# Segment: 2, 11
# Grid segment shape: (1000, 1000)
# Segment: 2, 12
# Grid segment shape: (1000, 1000)
# Segment: 2, 13
# Grid segment shape: (1000, 1000)
# Segment: 2, 14
# Grid segment shape: (1000, 1000)
# Segment: 2, 15
# Grid segment shape: (1000, 1000)
# Segment: 2, 16
# Grid segment shape: (1000, 1000)
# Segment: 2, 17
# Grid segment shape: (1000, 17)
# Segment: 3, 0
# Grid segment shape: (1000, 1000)
# Segment: 3, 1
# Grid segment shape: (1000, 1000)
# Segment: 3, 2
# Grid segment shape: (1000, 1000)
# Segment: 3, 3
# Grid segment shape: (1000, 1000)
# Segment: 3, 4
# Grid segment shape: (1000, 1000)
# Segment: 3, 5
# Grid segment shape: (1000, 1000)
# Segment: 3, 6
# Grid segment shape: (1000, 1000)
# Segment: 3, 7
# Grid segment shape: (1000, 1000)
# Segment: 3, 8
# Grid segment shape: (1000, 1000)
# Segment: 3, 9
# Grid segment shape: (1000, 1000)
# Segment: 3, 10
# Grid segment shape: (1000, 1000)
# Segment: 3, 11
# Grid segment shape: (1000, 1000)
# Segment: 3, 12
# Grid segment shape: (1000, 1000)
# Segment: 3, 13
# Grid segment shape: (1000, 1000)
# Segment: 3, 14
# Grid segment shape: (1000, 1000)
# Segment: 3, 15
# Grid segment shape: (1000, 1000)
# Segment: 3, 16
# Grid segment shape: (1000, 1000)
# Segment: 3, 17
# Grid segment shape: (1000, 17)
# Segment: 4, 0
# Grid segment shape: (1000, 1000)
# Segment: 4, 1
# Grid segment shape: (1000, 1000)
# Segment: 4, 2
# Grid segment shape: (1000, 1000)
# Segment: 4, 3
# Grid segment shape: (1000, 1000)
# Segment: 4, 4
# Grid segment shape: (1000, 1000)
# Segment: 4, 5
# Grid segment shape: (1000, 1000)
# Segment: 4, 6
# Grid segment shape: (1000, 1000)
# Segment: 4, 7
# Grid segment shape: (1000, 1000)
# Segment: 4, 8
# Grid segment shape: (1000, 1000)
# Segment: 4, 9
# Grid segment shape: (1000, 1000)
# Segment: 4, 10
# Grid segment shape: (1000, 1000)
# Segment: 4, 11
# Grid segment shape: (1000, 1000)
# Segment: 4, 12
# Grid segment shape: (1000, 1000)
# Segment: 4, 13
# Grid segment shape: (1000, 1000)
# Segment: 4, 14
# Grid segment shape: (1000, 1000)
# Segment: 4, 15
# Grid segment shape: (1000, 1000)
# Segment: 4, 16
# Grid segment shape: (1000, 1000)
# Segment: 4, 17
# Grid segment shape: (1000, 17)
# Segment: 5, 0
# Grid segment shape: (1000, 1000)
# Segment: 5, 1
# Grid segment shape: (1000, 1000)
# Segment: 5, 2
# Grid segment shape: (1000, 1000)
# Segment: 5, 3
# Grid segment shape: (1000, 1000)
# Segment: 5, 4
# Grid segment shape: (1000, 1000)
# Segment: 5, 5
# Grid segment shape: (1000, 1000)
# Segment: 5, 6
# Grid segment shape: (1000, 1000)
# Segment: 5, 7
# Grid segment shape: (1000, 1000)
# Segment: 5, 8
# Grid segment shape: (1000, 1000)
# Segment: 5, 9
# Grid segment shape: (1000, 1000)
# Segment: 5, 10
# Grid segment shape: (1000, 1000)
# Segment: 5, 11
# Grid segment shape: (1000, 1000)
# Segment: 5, 12
# Grid segment shape: (1000, 1000)
# Segment: 5, 13
# Grid segment shape: (1000, 1000)
# Segment: 5, 14
# Grid segment shape: (1000, 1000)
# Segment: 5, 15
# Grid segment shape: (1000, 1000)
# Segment: 5, 16
# Grid segment shape: (1000, 1000)
# Segment: 5, 17
# Grid segment shape: (1000, 17)
# Segment: 6, 0
# Grid segment shape: (1000, 1000)
# Segment: 6, 1
# Grid segment shape: (1000, 1000)
# Segment: 6, 2
# Grid segment shape: (1000, 1000)
# Segment: 6, 3
# Grid segment shape: (1000, 1000)
# Segment: 6, 4
# Grid segment shape: (1000, 1000)
# Segment: 6, 5
# Grid segment shape: (1000, 1000)
# Segment: 6, 6
# Grid segment shape: (1000, 1000)
# Segment: 6, 7
# Grid segment shape: (1000, 1000)
# Segment: 6, 8
# Grid segment shape: (1000, 1000)
# Segment: 6, 9
# Grid segment shape: (1000, 1000)
# Segment: 6, 10
# Grid segment shape: (1000, 1000)
# Segment: 6, 11
# Grid segment shape: (1000, 1000)
# Segment: 6, 12
# Grid segment shape: (1000, 1000)
# Segment: 6, 13
# Grid segment shape: (1000, 1000)
# Segment: 6, 14
# Grid segment shape: (1000, 1000)
# Segment: 6, 15
# Grid segment shape: (1000, 1000)
# Segment: 6, 16
# Grid segment shape: (1000, 1000)
# Segment: 6, 17
# Grid segment shape: (1000, 17)
# Segment: 7, 0
# Grid segment shape: (1000, 1000)
# Segment: 7, 1
# Grid segment shape: (1000, 1000)
# Segment: 7, 2
# Grid segment shape: (1000, 1000)
# Segment: 7, 3
# Grid segment shape: (1000, 1000)
# Segment: 7, 4
# Grid segment shape: (1000, 1000)
# Segment: 7, 5
# Grid segment shape: (1000, 1000)
# Segment: 7, 6
# Grid segment shape: (1000, 1000)
# Segment: 7, 7
# Grid segment shape: (1000, 1000)
# Segment: 7, 8
# Grid segment shape: (1000, 1000)
# Segment: 7, 9
# Grid segment shape: (1000, 1000)
# Segment: 7, 10
# Grid segment shape: (1000, 1000)
# Segment: 7, 11
# Grid segment shape: (1000, 1000)
# Segment: 7, 12
# Grid segment shape: (1000, 1000)
# Segment: 7, 13
# Grid segment shape: (1000, 1000)
# Segment: 7, 14
# Grid segment shape: (1000, 1000)
# Segment: 7, 15
# Grid segment shape: (1000, 1000)
# Segment: 7, 16
# Grid segment shape: (1000, 1000)
# Segment: 7, 17
# Grid segment shape: (1000, 17)
# Segment: 8, 0
# Grid segment shape: (1000, 1000)
# Segment: 8, 1
# Grid segment shape: (1000, 1000)
# Segment: 8, 2
# Grid segment shape: (1000, 1000)
# Segment: 8, 3
# Grid segment shape: (1000, 1000)
# Segment: 8, 4
# Grid segment shape: (1000, 1000)
# Segment: 8, 5
# Grid segment shape: (1000, 1000)
# Segment: 8, 6
# Grid segment shape: (1000, 1000)
# Segment: 8, 7
# Grid segment shape: (1000, 1000)
# Segment: 8, 8
# Grid segment shape: (1000, 1000)
# Segment: 8, 9
# Grid segment shape: (1000, 1000)
# Segment: 8, 10
# Grid segment shape: (1000, 1000)
# Segment: 8, 11
# Grid segment shape: (1000, 1000)
# Segment: 8, 12
# Grid segment shape: (1000, 1000)
# Segment: 8, 13
# Grid segment shape: (1000, 1000)
# Segment: 8, 14
# Grid segment shape: (1000, 1000)
# Segment: 8, 15
# Grid segment shape: (1000, 1000)
# Segment: 8, 16
# Grid segment shape: (1000, 1000)
# Segment: 8, 17
# Grid segment shape: (1000, 17)
# Segment: 9, 0
# Grid segment shape: (1000, 1000)
# Segment: 9, 1
# Grid segment shape: (1000, 1000)
# Segment: 9, 2
# Grid segment shape: (1000, 1000)
# Segment: 9, 3
# Grid segment shape: (1000, 1000)
# Segment: 9, 4
# Grid segment shape: (1000, 1000)
# Segment: 9, 5
# Grid segment shape: (1000, 1000)
# Segment: 9, 6
# Grid segment shape: (1000, 1000)
# Segment: 9, 7
# Grid segment shape: (1000, 1000)
# Segment: 9, 8
# Grid segment shape: (1000, 1000)
# Segment: 9, 9
# Grid segment shape: (1000, 1000)
# Segment: 9, 10
# Grid segment shape: (1000, 1000)
# Segment: 9, 11
# Grid segment shape: (1000, 1000)
# Segment: 9, 12
# Grid segment shape: (1000, 1000)
# Segment: 9, 13
# Grid segment shape: (1000, 1000)
# Segment: 9, 14
# Grid segment shape: (1000, 1000)
# Segment: 9, 15
# Grid segment shape: (1000, 1000)
# Segment: 9, 16
# Grid segment shape: (1000, 1000)
# Segment: 9, 17
# Grid segment shape: (1000, 17)
# Segment: 10, 0
# Grid segment shape: (1000, 1000)
# Segment: 10, 1
# Grid segment shape: (1000, 1000)
# Segment: 10, 2
# Grid segment shape: (1000, 1000)
# Segment: 10, 3
# Grid segment shape: (1000, 1000)
# Segment: 10, 4
# Grid segment shape: (1000, 1000)
# Segment: 10, 5
# Grid segment shape: (1000, 1000)
# Segment: 10, 6
# Grid segment shape: (1000, 1000)
# Segment: 10, 7
# Grid segment shape: (1000, 1000)
# Segment: 10, 8
# Grid segment shape: (1000, 1000)
# Segment: 10, 9
# Grid segment shape: (1000, 1000)
# Segment: 10, 10
# Grid segment shape: (1000, 1000)
# Segment: 10, 11
# Grid segment shape: (1000, 1000)
# Segment: 10, 12
# Grid segment shape: (1000, 1000)
# Segment: 10, 13
# Grid segment shape: (1000, 1000)
# Segment: 10, 14
# Grid segment shape: (1000, 1000)
# Segment: 10, 15
# Grid segment shape: (1000, 1000)
# Segment: 10, 16
# Grid segment shape: (1000, 1000)
# Segment: 10, 17
# Grid segment shape: (1000, 17)
# Segment: 11, 0
# Grid segment shape: (1000, 1000)
# Segment: 11, 1
# Grid segment shape: (1000, 1000)
# Segment: 11, 2
# Grid segment shape: (1000, 1000)
# Segment: 11, 3
# Grid segment shape: (1000, 1000)
# Segment: 11, 4
# Grid segment shape: (1000, 1000)
# Segment: 11, 5
# Grid segment shape: (1000, 1000)
# Segment: 11, 6
# Grid segment shape: (1000, 1000)
# Segment: 11, 7
# Grid segment shape: (1000, 1000)
# Segment: 11, 8
# Grid segment shape: (1000, 1000)
# Segment: 11, 9
# Grid segment shape: (1000, 1000)
# Segment: 11, 10
# Grid segment shape: (1000, 1000)
# Segment: 11, 11
# Grid segment shape: (1000, 1000)
# Segment: 11, 12
# Grid segment shape: (1000, 1000)
# Segment: 11, 13
# Grid segment shape: (1000, 1000)
# Segment: 11, 14
# Grid segment shape: (1000, 1000)
# Segment: 11, 15
# Grid segment shape: (1000, 1000)
# Segment: 11, 16
# Grid segment shape: (1000, 1000)
# Segment: 11, 17
# Grid segment shape: (1000, 17)
# Segment: 12, 0
# Grid segment shape: (1000, 1000)
# Segment: 12, 1
# Grid segment shape: (1000, 1000)
# Segment: 12, 2
# Grid segment shape: (1000, 1000)
# Segment: 12, 3
# Grid segment shape: (1000, 1000)
# Segment: 12, 4
# Grid segment shape: (1000, 1000)
# Segment: 12, 5
# Grid segment shape: (1000, 1000)
# Segment: 12, 6
# Grid segment shape: (1000, 1000)
# Segment: 12, 7
# Grid segment shape: (1000, 1000)
# Segment: 12, 8
# Grid segment shape: (1000, 1000)
# Segment: 12, 9
# Grid segment shape: (1000, 1000)
# Segment: 12, 10
# Grid segment shape: (1000, 1000)
# Segment: 12, 11
# Grid segment shape: (1000, 1000)
# Segment: 12, 12
# Grid segment shape: (1000, 1000)
# Segment: 12, 13
# Grid segment shape: (1000, 1000)
# Segment: 12, 14
# Grid segment shape: (1000, 1000)
# Segment: 12, 15
# Grid segment shape: (1000, 1000)
# Segment: 12, 16
# Grid segment shape: (1000, 1000)
# Segment: 12, 17
# Grid segment shape: (1000, 17)
# Segment: 13, 0
# Grid segment shape: (1000, 1000)
# Segment: 13, 1
# Grid segment shape: (1000, 1000)
# Segment: 13, 2
# Grid segment shape: (1000, 1000)
# Segment: 13, 3
# Grid segment shape: (1000, 1000)
# Segment: 13, 4
# Grid segment shape: (1000, 1000)
# Segment: 13, 5
# Grid segment shape: (1000, 1000)
# Segment: 13, 6
# Grid segment shape: (1000, 1000)
# Segment: 13, 7
# Grid segment shape: (1000, 1000)
# Segment: 13, 8
# Grid segment shape: (1000, 1000)
# Segment: 13, 9
# Grid segment shape: (1000, 1000)
# Segment: 13, 10
# Grid segment shape: (1000, 1000)
# Segment: 13, 11
# Grid segment shape: (1000, 1000)
# Segment: 13, 12
# Grid segment shape: (1000, 1000)
# Segment: 13, 13
# Grid segment shape: (1000, 1000)
# Segment: 13, 14
# Grid segment shape: (1000, 1000)
# Segment: 13, 15
# Grid segment shape: (1000, 1000)
# Segment: 13, 16
# Grid segment shape: (1000, 1000)
# Segment: 13, 17
# Grid segment shape: (1000, 17)
# Segment: 14, 0
# Grid segment shape: (1000, 1000)
# Segment: 14, 1
# Grid segment shape: (1000, 1000)
# Segment: 14, 2
# Grid segment shape: (1000, 1000)
# Segment: 14, 3
# Grid segment shape: (1000, 1000)
# Segment: 14, 4
# Grid segment shape: (1000, 1000)
# Segment: 14, 5
# Grid segment shape: (1000, 1000)
# Segment: 14, 6
# Grid segment shape: (1000, 1000)
# Segment: 14, 7
# Grid segment shape: (1000, 1000)
# Segment: 14, 8
# Grid segment shape: (1000, 1000)
# Segment: 14, 9
# Grid segment shape: (1000, 1000)
# Segment: 14, 10
# Grid segment shape: (1000, 1000)
# Segment: 14, 11
# Grid segment shape: (1000, 1000)
# Segment: 14, 12
# Grid segment shape: (1000, 1000)
# Segment: 14, 13
# Grid segment shape: (1000, 1000)
# Segment: 14, 14
# Grid segment shape: (1000, 1000)
# Segment: 14, 15
# Grid segment shape: (1000, 1000)
# Segment: 14, 16
# Grid segment shape: (1000, 1000)
# Segment: 14, 17
# Grid segment shape: (1000, 17)
# Segment: 15, 0
# Grid segment shape: (1000, 1000)
# Segment: 15, 1
# Grid segment shape: (1000, 1000)
# Segment: 15, 2
# Grid segment shape: (1000, 1000)
# Segment: 15, 3
# Grid segment shape: (1000, 1000)
# Segment: 15, 4
# Grid segment shape: (1000, 1000)
# Segment: 15, 5
# Grid segment shape: (1000, 1000)
# Segment: 15, 6
# Grid segment shape: (1000, 1000)
# Segment: 15, 7
# Grid segment shape: (1000, 1000)
# Segment: 15, 8
# Grid segment shape: (1000, 1000)
# Segment: 15, 9
# Grid segment shape: (1000, 1000)
# Segment: 15, 10
# Grid segment shape: (1000, 1000)
# Segment: 15, 11
# Grid segment shape: (1000, 1000)
# Segment: 15, 12
# Grid segment shape: (1000, 1000)
# Segment: 15, 13
# Grid segment shape: (1000, 1000)
# Segment: 15, 14
# Grid segment shape: (1000, 1000)
# Segment: 15, 15
# Grid segment shape: (1000, 1000)
# Segment: 15, 16
# Grid segment shape: (1000, 1000)
# Segment: 15, 17
# Grid segment shape: (1000, 17)
# Segment: 16, 0
# Grid segment shape: (1000, 1000)
# Segment: 16, 1
# Grid segment shape: (1000, 1000)
# Segment: 16, 2
# Grid segment shape: (1000, 1000)
# Segment: 16, 3
# Grid segment shape: (1000, 1000)
# Segment: 16, 4
# Grid segment shape: (1000, 1000)
# Segment: 16, 5
# Grid segment shape: (1000, 1000)
# Segment: 16, 6
# Grid segment shape: (1000, 1000)
# Segment: 16, 7
# Grid segment shape: (1000, 1000)
# Segment: 16, 8
# Grid segment shape: (1000, 1000)
# Segment: 16, 9
# Grid segment shape: (1000, 1000)
# Segment: 16, 10
# Grid segment shape: (1000, 1000)
# Segment: 16, 11
# Grid segment shape: (1000, 1000)
# Segment: 16, 12
# Grid segment shape: (1000, 1000)
# Segment: 16, 13
# Grid segment shape: (1000, 1000)
# Segment: 16, 14
# Grid segment shape: (1000, 1000)
# Segment: 16, 15
# Grid segment shape: (1000, 1000)
# Segment: 16, 16
# Grid segment shape: (1000, 1000)
# Segment: 16, 17
# Grid segment shape: (1000, 17)
# Segment: 17, 0
# Grid segment shape: (1000, 1000)
# Segment: 17, 1
# Grid segment shape: (1000, 1000)
# Segment: 17, 2
# Grid segment shape: (1000, 1000)
# Segment: 17, 3
# Grid segment shape: (1000, 1000)
# Segment: 17, 4
# Grid segment shape: (1000, 1000)
# Segment: 17, 5
# Grid segment shape: (1000, 1000)
# Segment: 17, 6
# Grid segment shape: (1000, 1000)
# Segment: 17, 7
# Grid segment shape: (1000, 1000)
# Segment: 17, 8
# Grid segment shape: (1000, 1000)
# Segment: 17, 9
# Grid segment shape: (1000, 1000)
# Segment: 17, 10
# Grid segment shape: (1000, 1000)
# Segment: 17, 11
# Grid segment shape: (1000, 1000)
# Segment: 17, 12
# Grid segment shape: (1000, 1000)
# Segment: 17, 13
# Grid segment shape: (1000, 1000)
# Segment: 17, 14
# Grid segment shape: (1000, 1000)
# Segment: 17, 15
# Grid segment shape: (1000, 1000)
# Segment: 17, 16
# Grid segment shape: (1000, 1000)
# Segment: 17, 17
# Grid segment shape: (1000, 17)
# Segment: 18, 0
# Grid segment shape: (1000, 1000)
# Segment: 18, 1
# Grid segment shape: (1000, 1000)
# Segment: 18, 2
# Grid segment shape: (1000, 1000)
# Segment: 18, 3
# Grid segment shape: (1000, 1000)
# Segment: 18, 4
# Grid segment shape: (1000, 1000)
# Segment: 18, 5
# Grid segment shape: (1000, 1000)
# Segment: 18, 6
# Grid segment shape: (1000, 1000)
# Segment: 18, 7
# Grid segment shape: (1000, 1000)
# Segment: 18, 8
# Grid segment shape: (1000, 1000)
# Segment: 18, 9
# Grid segment shape: (1000, 1000)
# Segment: 18, 10
# Grid segment shape: (1000, 1000)
# Segment: 18, 11
# Grid segment shape: (1000, 1000)
# Segment: 18, 12
# Grid segment shape: (1000, 1000)
# Segment: 18, 13
# Grid segment shape: (1000, 1000)
# Segment: 18, 14
# Grid segment shape: (1000, 1000)
# Segment: 18, 15
# Grid segment shape: (1000, 1000)
# Segment: 18, 16
# Grid segment shape: (1000, 1000)
# Segment: 18, 17
# Grid segment shape: (1000, 17)
# Segment: 19, 0
# Grid segment shape: (1000, 1000)
# Segment: 19, 1
# Grid segment shape: (1000, 1000)
# Segment: 19, 2
# Grid segment shape: (1000, 1000)
# Segment: 19, 3
# Grid segment shape: (1000, 1000)
# Segment: 19, 4
# Grid segment shape: (1000, 1000)
# Segment: 19, 5
# Grid segment shape: (1000, 1000)
# Segment: 19, 6
# Grid segment shape: (1000, 1000)
# Segment: 19, 7
# Grid segment shape: (1000, 1000)
# Segment: 19, 8
# Grid segment shape: (1000, 1000)
# Segment: 19, 9
# Grid segment shape: (1000, 1000)
# Segment: 19, 10
# Grid segment shape: (1000, 1000)
# Segment: 19, 11
# Grid segment shape: (1000, 1000)
# Segment: 19, 12
# Grid segment shape: (1000, 1000)
# Segment: 19, 13
# Grid segment shape: (1000, 1000)
# Segment: 19, 14
# Grid segment shape: (1000, 1000)
# Segment: 19, 15
# Grid segment shape: (1000, 1000)
# Segment: 19, 16
# Grid segment shape: (1000, 1000)
# Segment: 19, 17
# Grid segment shape: (1000, 17)
# Segment: 20, 0
# Grid segment shape: (1000, 1000)
# Segment: 20, 1
# Grid segment shape: (1000, 1000)
# Segment: 20, 2
# Grid segment shape: (1000, 1000)
# Segment: 20, 3
# Grid segment shape: (1000, 1000)
# Segment: 20, 4
# Grid segment shape: (1000, 1000)
# Segment: 20, 5
# Grid segment shape: (1000, 1000)
# Segment: 20, 6
# Grid segment shape: (1000, 1000)
# Segment: 20, 7
# Grid segment shape: (1000, 1000)
# Segment: 20, 8
# Grid segment shape: (1000, 1000)
# Segment: 20, 9
# Grid segment shape: (1000, 1000)
# Segment: 20, 10
# Grid segment shape: (1000, 1000)
# Segment: 20, 11
# Grid segment shape: (1000, 1000)
# Segment: 20, 12
# Grid segment shape: (1000, 1000)
# Segment: 20, 13
# Grid segment shape: (1000, 1000)
# Segment: 20, 14
# Grid segment shape: (1000, 1000)
# Segment: 20, 15
# Grid segment shape: (1000, 1000)
# Segment: 20, 16
# Grid segment shape: (1000, 1000)
# Segment: 20, 17
# Grid segment shape: (1000, 17)
# Segment: 21, 0
# Grid segment shape: (1000, 1000)
# Segment: 21, 1
# Grid segment shape: (1000, 1000)
# Segment: 21, 2
# Grid segment shape: (1000, 1000)
# Segment: 21, 3
# Grid segment shape: (1000, 1000)
# Segment: 21, 4
# Grid segment shape: (1000, 1000)
# Segment: 21, 5
# Grid segment shape: (1000, 1000)
# Segment: 21, 6
# Grid segment shape: (1000, 1000)
# Segment: 21, 7
# Grid segment shape: (1000, 1000)
# Segment: 21, 8
# Grid segment shape: (1000, 1000)
# Segment: 21, 9
# Grid segment shape: (1000, 1000)
# Segment: 21, 10
# Grid segment shape: (1000, 1000)
# Segment: 21, 11
# Grid segment shape: (1000, 1000)
# Segment: 21, 12
# Grid segment shape: (1000, 1000)
# Segment: 21, 13
# Grid segment shape: (1000, 1000)
# Segment: 21, 14
# Grid segment shape: (1000, 1000)
# Segment: 21, 15
# Grid segment shape: (1000, 1000)
# Segment: 21, 16
# Grid segment shape: (1000, 1000)
# Segment: 21, 17
# Grid segment shape: (1000, 17)
# Segment: 22, 0
# Grid segment shape: (1000, 1000)
# Segment: 22, 1
# Grid segment shape: (1000, 1000)
# Segment: 22, 2
# Grid segment shape: (1000, 1000)
# Segment: 22, 3
# Grid segment shape: (1000, 1000)
# Segment: 22, 4
# Grid segment shape: (1000, 1000)
# Segment: 22, 5
# Grid segment shape: (1000, 1000)
# Segment: 22, 6
# Grid segment shape: (1000, 1000)
# Segment: 22, 7
# Grid segment shape: (1000, 1000)
# Segment: 22, 8
# Grid segment shape: (1000, 1000)
# Segment: 22, 9
# Grid segment shape: (1000, 1000)
# Segment: 22, 10
# Grid segment shape: (1000, 1000)
# Segment: 22, 11
# Grid segment shape: (1000, 1000)
# Segment: 22, 12
# Grid segment shape: (1000, 1000)
# Segment: 22, 13
# Grid segment shape: (1000, 1000)
# Segment: 22, 14
# Grid segment shape: (1000, 1000)
# Segment: 22, 15
# Grid segment shape: (1000, 1000)
# Segment: 22, 16
# Grid segment shape: (1000, 1000)
# Segment: 22, 17
# Grid segment shape: (1000, 17)
# Segment: 23, 0
# Grid segment shape: (1000, 1000)
# Segment: 23, 1
# Grid segment shape: (1000, 1000)
# Segment: 23, 2
# Grid segment shape: (1000, 1000)
# Segment: 23, 3
# Grid segment shape: (1000, 1000)
# Segment: 23, 4
# Grid segment shape: (1000, 1000)
# Segment: 23, 5
# Grid segment shape: (1000, 1000)
# Segment: 23, 6
# Grid segment shape: (1000, 1000)
# Segment: 23, 7
# Grid segment shape: (1000, 1000)
# Segment: 23, 8
# Grid segment shape: (1000, 1000)
# Segment: 23, 9
# Grid segment shape: (1000, 1000)
# Segment: 23, 10
# Grid segment shape: (1000, 1000)
# Segment: 23, 11
# Grid segment shape: (1000, 1000)
# Segment: 23, 12
# Grid segment shape: (1000, 1000)
# Segment: 23, 13
# Grid segment shape: (1000, 1000)
# Segment: 23, 14
# Grid segment shape: (1000, 1000)
# Segment: 23, 15
# Grid segment shape: (1000, 1000)
# Segment: 23, 16
# Grid segment shape: (1000, 1000)
# Segment: 23, 17
# Grid segment shape: (1000, 17)
# Segment: 24, 0
# Grid segment shape: (1000, 1000)
# Segment: 24, 1
# Grid segment shape: (1000, 1000)
# Segment: 24, 2
# Grid segment shape: (1000, 1000)
# Segment: 24, 3
# Grid segment shape: (1000, 1000)
# Segment: 24, 4
# Grid segment shape: (1000, 1000)
# Segment: 24, 5
# Grid segment shape: (1000, 1000)
# Segment: 24, 6
# Grid segment shape: (1000, 1000)
# Segment: 24, 7
# Grid segment shape: (1000, 1000)
# Segment: 24, 8
# Grid segment shape: (1000, 1000)
# Segment: 24, 9
# Grid segment shape: (1000, 1000)
# Segment: 24, 10
# Grid segment shape: (1000, 1000)
# Segment: 24, 11
# Grid segment shape: (1000, 1000)
# Segment: 24, 12
# Grid segment shape: (1000, 1000)
# Segment: 24, 13
# Grid segment shape: (1000, 1000)
# Segment: 24, 14
# Grid segment shape: (1000, 1000)
# Segment: 24, 15
# Grid segment shape: (1000, 1000)
# Segment: 24, 16
# Grid segment shape: (1000, 1000)
# Segment: 24, 17
# Grid segment shape: (1000, 17)
# Segment: 25, 0
# Grid segment shape: (1000, 1000)
# Segment: 25, 1
# Grid segment shape: (1000, 1000)
# Segment: 25, 2
# Grid segment shape: (1000, 1000)
# Segment: 25, 3
# Grid segment shape: (1000, 1000)
# Segment: 25, 4
# Grid segment shape: (1000, 1000)
# Segment: 25, 5
# Grid segment shape: (1000, 1000)
# Segment: 25, 6
# Grid segment shape: (1000, 1000)
# Segment: 25, 7
# Grid segment shape: (1000, 1000)
# Segment: 25, 8
# Grid segment shape: (1000, 1000)
# Segment: 25, 9
# Grid segment shape: (1000, 1000)
# Segment: 25, 10
# Grid segment shape: (1000, 1000)
# Segment: 25, 11
# Grid segment shape: (1000, 1000)
# Segment: 25, 12
# Grid segment shape: (1000, 1000)
# Segment: 25, 13
# Grid segment shape: (1000, 1000)
# Segment: 25, 14
# Grid segment shape: (1000, 1000)
# Segment: 25, 15
# Grid segment shape: (1000, 1000)
# Segment: 25, 16
# Grid segment shape: (1000, 1000)
# Segment: 25, 17
# Grid segment shape: (1000, 17)
# Segment: 26, 0
# Grid segment shape: (1000, 1000)
# Segment: 26, 1
# Grid segment shape: (1000, 1000)
# Segment: 26, 2
# Grid segment shape: (1000, 1000)
# Segment: 26, 3
# Grid segment shape: (1000, 1000)
# Segment: 26, 4
# Grid segment shape: (1000, 1000)
# Segment: 26, 5
# Grid segment shape: (1000, 1000)
# Segment: 26, 6
# Grid segment shape: (1000, 1000)
# Segment: 26, 7
# Grid segment shape: (1000, 1000)
# Segment: 26, 8
# Grid segment shape: (1000, 1000)
# Segment: 26, 9
# Grid segment shape: (1000, 1000)
# Segment: 26, 10
# Grid segment shape: (1000, 1000)
# Segment: 26, 11
# Grid segment shape: (1000, 1000)
# Segment: 26, 12
# Grid segment shape: (1000, 1000)
# Segment: 26, 13
# Grid segment shape: (1000, 1000)
# Segment: 26, 14
# Grid segment shape: (1000, 1000)
# Segment: 26, 15
# Grid segment shape: (1000, 1000)
# Segment: 26, 16
# Grid segment shape: (1000, 1000)
# Segment: 26, 17
# Grid segment shape: (1000, 17)
# Segment: 27, 0
# Grid segment shape: (1000, 1000)
# Segment: 27, 1
# Grid segment shape: (1000, 1000)
# Segment: 27, 2
# Grid segment shape: (1000, 1000)
# Segment: 27, 3
# Grid segment shape: (1000, 1000)
# Segment: 27, 4
# Grid segment shape: (1000, 1000)
# Segment: 27, 5
# Grid segment shape: (1000, 1000)
# Segment: 27, 6
# Grid segment shape: (1000, 1000)
# Segment: 27, 7
# Grid segment shape: (1000, 1000)
# Segment: 27, 8
# Grid segment shape: (1000, 1000)
# Segment: 27, 9
# Grid segment shape: (1000, 1000)
# Segment: 27, 10
# Grid segment shape: (1000, 1000)
# Segment: 27, 11
# Grid segment shape: (1000, 1000)
# Segment: 27, 12
# Grid segment shape: (1000, 1000)
# Segment: 27, 13
# Grid segment shape: (1000, 1000)
# Segment: 27, 14
# Grid segment shape: (1000, 1000)
# Segment: 27, 15
# Grid segment shape: (1000, 1000)
# Segment: 27, 16
# Grid segment shape: (1000, 1000)
# Segment: 27, 17
# Grid segment shape: (1000, 17)
# Segment: 28, 0
# Grid segment shape: (1000, 1000)
# Segment: 28, 1
# Grid segment shape: (1000, 1000)
# Segment: 28, 2
# Grid segment shape: (1000, 1000)
# Segment: 28, 3
# Grid segment shape: (1000, 1000)
# Segment: 28, 4
# Grid segment shape: (1000, 1000)
# Segment: 28, 5
# Grid segment shape: (1000, 1000)
# Segment: 28, 6
# Grid segment shape: (1000, 1000)
# Segment: 28, 7
# Grid segment shape: (1000, 1000)
# Segment: 28, 8
# Grid segment shape: (1000, 1000)
# Segment: 28, 9
# Grid segment shape: (1000, 1000)
# Segment: 28, 10
# Grid segment shape: (1000, 1000)
# Segment: 28, 11
# Grid segment shape: (1000, 1000)
# Segment: 28, 12
# Grid segment shape: (1000, 1000)
# Segment: 28, 13
# Grid segment shape: (1000, 1000)
# Segment: 28, 14
# Grid segment shape: (1000, 1000)
# Segment: 28, 15
# Grid segment shape: (1000, 1000)
# Segment: 28, 16
# Grid segment shape: (1000, 1000)
# Segment: 28, 17
# Grid segment shape: (1000, 17)
# Segment: 29, 0
# Grid segment shape: (682, 1000)
# Segment: 29, 1
# Grid segment shape: (682, 1000)
# Segment: 29, 2
# Grid segment shape: (682, 1000)
# Segment: 29, 3
# Grid segment shape: (682, 1000)
# Segment: 29, 4
# Grid segment shape: (682, 1000)
# Segment: 29, 5
# Grid segment shape: (682, 1000)
# Segment: 29, 6
# Grid segment shape: (682, 1000)
# Segment: 29, 7
# Grid segment shape: (682, 1000)
# Segment: 29, 8
# Grid segment shape: (682, 1000)
# Segment: 29, 9
# Grid segment shape: (682, 1000)
# Segment: 29, 10
# Grid segment shape: (682, 1000)
# Segment: 29, 11
# Grid segment shape: (682, 1000)
# Segment: 29, 12
# Grid segment shape: (682, 1000)
# Segment: 29, 13
# Grid segment shape: (682, 1000)
# Segment: 29, 14
# Grid segment shape: (682, 1000)
# Segment: 29, 15
# Grid segment shape: (682, 1000)
# Segment: 29, 16
# Grid segment shape: (682, 1000)
# Segment: 29, 17
# Grid segment shape: (682, 17)

# %%
loader.add_elevation_to_grid(grid_manager)
# Out:
# Rozpoczynam dodawanie wysokości dla 30x18 segmentów...
# Zapisano wysokość: segment [0, 0]
# Zapisano wysokość: segment [0, 1]
# Zapisano wysokość: segment [0, 2]
# Zapisano wysokość: segment [0, 3]
# Zapisano wysokość: segment [0, 4]
# Zapisano wysokość: segment [0, 5]
# Zapisano wysokość: segment [0, 6]
# Zapisano wysokość: segment [0, 7]
# Zapisano wysokość: segment [0, 8]
# Zapisano wysokość: segment [0, 9]
# Zapisano wysokość: segment [0, 10]
# Zapisano wysokość: segment [0, 11]
# Zapisano wysokość: segment [0, 12]
# Zapisano wysokość: segment [0, 13]
# Zapisano wysokość: segment [0, 14]
# Zapisano wysokość: segment [0, 15]
# Zapisano wysokość: segment [0, 16]
# Zapisano wysokość: segment [0, 17]
# Zapisano wysokość: segment [1, 0]
# Zapisano wysokość: segment [1, 1]
# Zapisano wysokość: segment [1, 2]
# Zapisano wysokość: segment [1, 3]
# Zapisano wysokość: segment [1, 4]
# Zapisano wysokość: segment [1, 5]
# Zapisano wysokość: segment [1, 6]
# Zapisano wysokość: segment [1, 7]
# Zapisano wysokość: segment [1, 8]
# Zapisano wysokość: segment [1, 9]
# Zapisano wysokość: segment [1, 10]
# Zapisano wysokość: segment [1, 11]
# Zapisano wysokość: segment [1, 12]
# Zapisano wysokość: segment [1, 13]
# Zapisano wysokość: segment [1, 14]
# Zapisano wysokość: segment [1, 15]
# Zapisano wysokość: segment [1, 16]
# Zapisano wysokość: segment [1, 17]
# Zapisano wysokość: segment [2, 0]
# Zapisano wysokość: segment [2, 1]
# Zapisano wysokość: segment [2, 2]
# Zapisano wysokość: segment [2, 3]
# Zapisano wysokość: segment [2, 4]
# Zapisano wysokość: segment [2, 5]
# Zapisano wysokość: segment [2, 6]
# Zapisano wysokość: segment [2, 7]
# Zapisano wysokość: segment [2, 8]
# Zapisano wysokość: segment [2, 9]
# Zapisano wysokość: segment [2, 10]
# Zapisano wysokość: segment [2, 11]
# Zapisano wysokość: segment [2, 12]
# Zapisano wysokość: segment [2, 13]
# Zapisano wysokość: segment [2, 14]
# Zapisano wysokość: segment [2, 15]
# Zapisano wysokość: segment [2, 16]
# Zapisano wysokość: segment [2, 17]
# Zapisano wysokość: segment [3, 0]
# Zapisano wysokość: segment [3, 1]
# Zapisano wysokość: segment [3, 2]
# Zapisano wysokość: segment [3, 3]
# Zapisano wysokość: segment [3, 4]
# Zapisano wysokość: segment [3, 5]
# Zapisano wysokość: segment [3, 6]
# Zapisano wysokość: segment [3, 7]
# Zapisano wysokość: segment [3, 8]
# Zapisano wysokość: segment [3, 9]
# Zapisano wysokość: segment [3, 10]
# Zapisano wysokość: segment [3, 11]
# Zapisano wysokość: segment [3, 12]
# Zapisano wysokość: segment [3, 13]
# Zapisano wysokość: segment [3, 14]
# Zapisano wysokość: segment [3, 15]
# Zapisano wysokość: segment [3, 16]
# Zapisano wysokość: segment [3, 17]
# Zapisano wysokość: segment [4, 0]
# Zapisano wysokość: segment [4, 1]
# Zapisano wysokość: segment [4, 2]
# Zapisano wysokość: segment [4, 3]
# Zapisano wysokość: segment [4, 4]
# Zapisano wysokość: segment [4, 5]
# Zapisano wysokość: segment [4, 6]
# Zapisano wysokość: segment [4, 7]
# Zapisano wysokość: segment [4, 8]
# Zapisano wysokość: segment [4, 9]
# Zapisano wysokość: segment [4, 10]
# Zapisano wysokość: segment [4, 11]
# Zapisano wysokość: segment [4, 12]
# Zapisano wysokość: segment [4, 13]
# Zapisano wysokość: segment [4, 14]
# Zapisano wysokość: segment [4, 15]
# Zapisano wysokość: segment [4, 16]
# Zapisano wysokość: segment [4, 17]
# Zapisano wysokość: segment [5, 0]
# Zapisano wysokość: segment [5, 1]
# Zapisano wysokość: segment [5, 2]
# Zapisano wysokość: segment [5, 3]
# Zapisano wysokość: segment [5, 4]
# Zapisano wysokość: segment [5, 5]
# Zapisano wysokość: segment [5, 6]
# Zapisano wysokość: segment [5, 7]
# Zapisano wysokość: segment [5, 8]
# Zapisano wysokość: segment [5, 9]
# Zapisano wysokość: segment [5, 10]
# Zapisano wysokość: segment [5, 11]
# Zapisano wysokość: segment [5, 12]
# Zapisano wysokość: segment [5, 13]
# Zapisano wysokość: segment [5, 14]
# Zapisano wysokość: segment [5, 15]
# Zapisano wysokość: segment [5, 16]
# Zapisano wysokość: segment [5, 17]
# Zapisano wysokość: segment [6, 0]
# Zapisano wysokość: segment [6, 1]
# Zapisano wysokość: segment [6, 2]
# Zapisano wysokość: segment [6, 3]
# Zapisano wysokość: segment [6, 4]
# Zapisano wysokość: segment [6, 5]
# Zapisano wysokość: segment [6, 6]
# Zapisano wysokość: segment [6, 7]
# Zapisano wysokość: segment [6, 8]
# Zapisano wysokość: segment [6, 9]
# Zapisano wysokość: segment [6, 10]
# Zapisano wysokość: segment [6, 11]
# Zapisano wysokość: segment [6, 12]
# Zapisano wysokość: segment [6, 13]
# Zapisano wysokość: segment [6, 14]
# Zapisano wysokość: segment [6, 15]
# Zapisano wysokość: segment [6, 16]
# Zapisano wysokość: segment [6, 17]
# Zapisano wysokość: segment [7, 0]
# Zapisano wysokość: segment [7, 1]
# Zapisano wysokość: segment [7, 2]
# Zapisano wysokość: segment [7, 3]
# Zapisano wysokość: segment [7, 4]
# Zapisano wysokość: segment [7, 5]
# Zapisano wysokość: segment [7, 6]
# Zapisano wysokość: segment [7, 7]
# Zapisano wysokość: segment [7, 8]
# Zapisano wysokość: segment [7, 9]
# Zapisano wysokość: segment [7, 10]
# Zapisano wysokość: segment [7, 11]
# Zapisano wysokość: segment [7, 12]
# Zapisano wysokość: segment [7, 13]
# Zapisano wysokość: segment [7, 14]
# Zapisano wysokość: segment [7, 15]
# Zapisano wysokość: segment [7, 16]
# Zapisano wysokość: segment [7, 17]
# Zapisano wysokość: segment [8, 0]
# Zapisano wysokość: segment [8, 1]
# Zapisano wysokość: segment [8, 2]
# Zapisano wysokość: segment [8, 3]
# Zapisano wysokość: segment [8, 4]
# Zapisano wysokość: segment [8, 5]
# Zapisano wysokość: segment [8, 6]
# Zapisano wysokość: segment [8, 7]
# Zapisano wysokość: segment [8, 8]
# Zapisano wysokość: segment [8, 9]
# Zapisano wysokość: segment [8, 10]
# Zapisano wysokość: segment [8, 11]
# Zapisano wysokość: segment [8, 12]
# Zapisano wysokość: segment [8, 13]
# Zapisano wysokość: segment [8, 14]
# Zapisano wysokość: segment [8, 15]
# Zapisano wysokość: segment [8, 16]
# Zapisano wysokość: segment [8, 17]
# Zapisano wysokość: segment [9, 0]
# Zapisano wysokość: segment [9, 1]
# Zapisano wysokość: segment [9, 2]
# Zapisano wysokość: segment [9, 3]
# Zapisano wysokość: segment [9, 4]
# Zapisano wysokość: segment [9, 5]
# Zapisano wysokość: segment [9, 6]
# Zapisano wysokość: segment [9, 7]
# Zapisano wysokość: segment [9, 8]
# Zapisano wysokość: segment [9, 9]
# Zapisano wysokość: segment [9, 10]
# Zapisano wysokość: segment [9, 11]
# Zapisano wysokość: segment [9, 12]
# Zapisano wysokość: segment [9, 13]
# Zapisano wysokość: segment [9, 14]
# Zapisano wysokość: segment [9, 15]
# Zapisano wysokość: segment [9, 16]
# Zapisano wysokość: segment [9, 17]
# Zapisano wysokość: segment [10, 0]
# Zapisano wysokość: segment [10, 1]
# Zapisano wysokość: segment [10, 2]
# Zapisano wysokość: segment [10, 3]
# Zapisano wysokość: segment [10, 4]
# Zapisano wysokość: segment [10, 5]
# Zapisano wysokość: segment [10, 6]
# Zapisano wysokość: segment [10, 7]
# Zapisano wysokość: segment [10, 8]
# Zapisano wysokość: segment [10, 9]
# Zapisano wysokość: segment [10, 10]
# Zapisano wysokość: segment [10, 11]
# Zapisano wysokość: segment [10, 12]
# Zapisano wysokość: segment [10, 13]
# Zapisano wysokość: segment [10, 14]
# Zapisano wysokość: segment [10, 15]
# Zapisano wysokość: segment [10, 16]
# Zapisano wysokość: segment [10, 17]
# Zapisano wysokość: segment [11, 0]
# Zapisano wysokość: segment [11, 1]
# Zapisano wysokość: segment [11, 2]
# Zapisano wysokość: segment [11, 3]
# Zapisano wysokość: segment [11, 4]
# Zapisano wysokość: segment [11, 5]
# Zapisano wysokość: segment [11, 6]
# Zapisano wysokość: segment [11, 7]
# Zapisano wysokość: segment [11, 8]
# Zapisano wysokość: segment [11, 9]
# Zapisano wysokość: segment [11, 10]
# Zapisano wysokość: segment [11, 11]
# Zapisano wysokość: segment [11, 12]
# Zapisano wysokość: segment [11, 13]
# Zapisano wysokość: segment [11, 14]
# Zapisano wysokość: segment [11, 15]
# Zapisano wysokość: segment [11, 16]
# Zapisano wysokość: segment [11, 17]
# Zapisano wysokość: segment [12, 0]
# Zapisano wysokość: segment [12, 1]
# Zapisano wysokość: segment [12, 2]
# Zapisano wysokość: segment [12, 3]
# Zapisano wysokość: segment [12, 4]
# Zapisano wysokość: segment [12, 5]
# Zapisano wysokość: segment [12, 6]
# Zapisano wysokość: segment [12, 7]
# Zapisano wysokość: segment [12, 8]
# Zapisano wysokość: segment [12, 9]
# Zapisano wysokość: segment [12, 10]
# Zapisano wysokość: segment [12, 11]
# Zapisano wysokość: segment [12, 12]
# Zapisano wysokość: segment [12, 13]
# Zapisano wysokość: segment [12, 14]
# Zapisano wysokość: segment [12, 15]
# Zapisano wysokość: segment [12, 16]
# Zapisano wysokość: segment [12, 17]
# Zapisano wysokość: segment [13, 0]
# Zapisano wysokość: segment [13, 1]
# Zapisano wysokość: segment [13, 2]
# Zapisano wysokość: segment [13, 3]
# Zapisano wysokość: segment [13, 4]
# Zapisano wysokość: segment [13, 5]
# Zapisano wysokość: segment [13, 6]
# Zapisano wysokość: segment [13, 7]
# Zapisano wysokość: segment [13, 8]
# Zapisano wysokość: segment [13, 9]
# Zapisano wysokość: segment [13, 10]
# Zapisano wysokość: segment [13, 11]
# Zapisano wysokość: segment [13, 12]
# Zapisano wysokość: segment [13, 13]
# Zapisano wysokość: segment [13, 14]
# Zapisano wysokość: segment [13, 15]
# Zapisano wysokość: segment [13, 16]
# Zapisano wysokość: segment [13, 17]
# Zapisano wysokość: segment [14, 0]
# Zapisano wysokość: segment [14, 1]
# Zapisano wysokość: segment [14, 2]
# Zapisano wysokość: segment [14, 3]
# Zapisano wysokość: segment [14, 4]
# Zapisano wysokość: segment [14, 5]
# Zapisano wysokość: segment [14, 6]
# Zapisano wysokość: segment [14, 7]
# Zapisano wysokość: segment [14, 8]
# Zapisano wysokość: segment [14, 9]
# Zapisano wysokość: segment [14, 10]
# Zapisano wysokość: segment [14, 11]
# Zapisano wysokość: segment [14, 12]
# Zapisano wysokość: segment [14, 13]
# Zapisano wysokość: segment [14, 14]
# Zapisano wysokość: segment [14, 15]
# Zapisano wysokość: segment [14, 16]
# Zapisano wysokość: segment [14, 17]
# Zapisano wysokość: segment [15, 0]
# Zapisano wysokość: segment [15, 1]
# Zapisano wysokość: segment [15, 2]
# Zapisano wysokość: segment [15, 3]
# Zapisano wysokość: segment [15, 4]
# Zapisano wysokość: segment [15, 5]
# Zapisano wysokość: segment [15, 6]
# Zapisano wysokość: segment [15, 7]
# Zapisano wysokość: segment [15, 8]
# Zapisano wysokość: segment [15, 9]
# Zapisano wysokość: segment [15, 10]
# Zapisano wysokość: segment [15, 11]
# Zapisano wysokość: segment [15, 12]
# Zapisano wysokość: segment [15, 13]
# Zapisano wysokość: segment [15, 14]
# Zapisano wysokość: segment [15, 15]
# Zapisano wysokość: segment [15, 16]
# Zapisano wysokość: segment [15, 17]
# Zapisano wysokość: segment [16, 0]
# Zapisano wysokość: segment [16, 1]
# Zapisano wysokość: segment [16, 2]
# Zapisano wysokość: segment [16, 3]
# Zapisano wysokość: segment [16, 4]
# Zapisano wysokość: segment [16, 5]
# Zapisano wysokość: segment [16, 6]
# Zapisano wysokość: segment [16, 7]
# Zapisano wysokość: segment [16, 8]
# Zapisano wysokość: segment [16, 9]
# Zapisano wysokość: segment [16, 10]
# Zapisano wysokość: segment [16, 11]
# Zapisano wysokość: segment [16, 12]
# Zapisano wysokość: segment [16, 13]
# Zapisano wysokość: segment [16, 14]
# Zapisano wysokość: segment [16, 15]
# Zapisano wysokość: segment [16, 16]
# Zapisano wysokość: segment [16, 17]
# Zapisano wysokość: segment [17, 0]
# Zapisano wysokość: segment [17, 1]
# Zapisano wysokość: segment [17, 2]
# Zapisano wysokość: segment [17, 3]
# Zapisano wysokość: segment [17, 4]
# Zapisano wysokość: segment [17, 5]
# Zapisano wysokość: segment [17, 6]
# Zapisano wysokość: segment [17, 7]
# Zapisano wysokość: segment [17, 8]
# Zapisano wysokość: segment [17, 9]
# Zapisano wysokość: segment [17, 10]
# Zapisano wysokość: segment [17, 11]
# Zapisano wysokość: segment [17, 12]
# Zapisano wysokość: segment [17, 13]
# Zapisano wysokość: segment [17, 14]
# Zapisano wysokość: segment [17, 15]
# Zapisano wysokość: segment [17, 16]
# Zapisano wysokość: segment [17, 17]
# Zapisano wysokość: segment [18, 0]
# Zapisano wysokość: segment [18, 1]
# Zapisano wysokość: segment [18, 2]
# Zapisano wysokość: segment [18, 3]
# Zapisano wysokość: segment [18, 4]
# Zapisano wysokość: segment [18, 5]
# Zapisano wysokość: segment [18, 6]
# Zapisano wysokość: segment [18, 7]
# Zapisano wysokość: segment [18, 8]
# Zapisano wysokość: segment [18, 9]
# Zapisano wysokość: segment [18, 10]
# Zapisano wysokość: segment [18, 11]
# Zapisano wysokość: segment [18, 12]
# Zapisano wysokość: segment [18, 13]
# Zapisano wysokość: segment [18, 14]
# Zapisano wysokość: segment [18, 15]
# Zapisano wysokość: segment [18, 16]
# Zapisano wysokość: segment [18, 17]
# Zapisano wysokość: segment [19, 0]
# Zapisano wysokość: segment [19, 1]
# Zapisano wysokość: segment [19, 2]
# Zapisano wysokość: segment [19, 3]
# Zapisano wysokość: segment [19, 4]
# Zapisano wysokość: segment [19, 5]
# Zapisano wysokość: segment [19, 6]
# Zapisano wysokość: segment [19, 7]
# Zapisano wysokość: segment [19, 8]
# Zapisano wysokość: segment [19, 9]
# Zapisano wysokość: segment [19, 10]
# Zapisano wysokość: segment [19, 11]
# Zapisano wysokość: segment [19, 12]
# Zapisano wysokość: segment [19, 13]
# Zapisano wysokość: segment [19, 14]
# Zapisano wysokość: segment [19, 15]
# Zapisano wysokość: segment [19, 16]
# Zapisano wysokość: segment [19, 17]
# Zapisano wysokość: segment [20, 0]
# Zapisano wysokość: segment [20, 1]
# Zapisano wysokość: segment [20, 2]
# Zapisano wysokość: segment [20, 3]
# Zapisano wysokość: segment [20, 4]
# Zapisano wysokość: segment [20, 5]
# Zapisano wysokość: segment [20, 6]
# Zapisano wysokość: segment [20, 7]
# Zapisano wysokość: segment [20, 8]
# Zapisano wysokość: segment [20, 9]
# Zapisano wysokość: segment [20, 10]
# Zapisano wysokość: segment [20, 11]
# Zapisano wysokość: segment [20, 12]
# Zapisano wysokość: segment [20, 13]
# Zapisano wysokość: segment [20, 14]
# Zapisano wysokość: segment [20, 15]
# Zapisano wysokość: segment [20, 16]
# Zapisano wysokość: segment [20, 17]
# Zapisano wysokość: segment [21, 0]
# Zapisano wysokość: segment [21, 1]
# Zapisano wysokość: segment [21, 2]
# Zapisano wysokość: segment [21, 3]
# Zapisano wysokość: segment [21, 4]
# Zapisano wysokość: segment [21, 5]
# Zapisano wysokość: segment [21, 6]
# Zapisano wysokość: segment [21, 7]
# Zapisano wysokość: segment [21, 8]
# Zapisano wysokość: segment [21, 9]
# Zapisano wysokość: segment [21, 10]
# Zapisano wysokość: segment [21, 11]
# Zapisano wysokość: segment [21, 12]
# Zapisano wysokość: segment [21, 13]
# Zapisano wysokość: segment [21, 14]
# Zapisano wysokość: segment [21, 15]
# Zapisano wysokość: segment [21, 16]
# Zapisano wysokość: segment [21, 17]
# Zapisano wysokość: segment [22, 0]
# Zapisano wysokość: segment [22, 1]
# Zapisano wysokość: segment [22, 2]
# Zapisano wysokość: segment [22, 3]
# Zapisano wysokość: segment [22, 4]
# Zapisano wysokość: segment [22, 5]
# Zapisano wysokość: segment [22, 6]
# Zapisano wysokość: segment [22, 7]
# Zapisano wysokość: segment [22, 8]
# Zapisano wysokość: segment [22, 9]
# Zapisano wysokość: segment [22, 10]
# Zapisano wysokość: segment [22, 11]
# Zapisano wysokość: segment [22, 12]
# Zapisano wysokość: segment [22, 13]
# Zapisano wysokość: segment [22, 14]
# Zapisano wysokość: segment [22, 15]
# Zapisano wysokość: segment [22, 16]
# Zapisano wysokość: segment [22, 17]
# Zapisano wysokość: segment [23, 0]
# Zapisano wysokość: segment [23, 1]
# Zapisano wysokość: segment [23, 2]
# Zapisano wysokość: segment [23, 3]
# Zapisano wysokość: segment [23, 4]
# Zapisano wysokość: segment [23, 5]
# Zapisano wysokość: segment [23, 6]
# Zapisano wysokość: segment [23, 7]
# Zapisano wysokość: segment [23, 8]
# Zapisano wysokość: segment [23, 9]
# Zapisano wysokość: segment [23, 10]
# Zapisano wysokość: segment [23, 11]
# Zapisano wysokość: segment [23, 12]
# Zapisano wysokość: segment [23, 13]
# Zapisano wysokość: segment [23, 14]
# Zapisano wysokość: segment [23, 15]
# Zapisano wysokość: segment [23, 16]
# Zapisano wysokość: segment [23, 17]
# Zapisano wysokość: segment [24, 0]
# Zapisano wysokość: segment [24, 1]
# Zapisano wysokość: segment [24, 2]
# Zapisano wysokość: segment [24, 3]
# Zapisano wysokość: segment [24, 4]
# Zapisano wysokość: segment [24, 5]
# Zapisano wysokość: segment [24, 6]
# Zapisano wysokość: segment [24, 7]
# Zapisano wysokość: segment [24, 8]
# Zapisano wysokość: segment [24, 9]
# Zapisano wysokość: segment [24, 10]
# Zapisano wysokość: segment [24, 11]
# Zapisano wysokość: segment [24, 12]
# Zapisano wysokość: segment [24, 13]
# Zapisano wysokość: segment [24, 14]
# Zapisano wysokość: segment [24, 15]
# Zapisano wysokość: segment [24, 16]
# Zapisano wysokość: segment [24, 17]
# Zapisano wysokość: segment [25, 0]
# Zapisano wysokość: segment [25, 1]
# Zapisano wysokość: segment [25, 2]
# Zapisano wysokość: segment [25, 3]
# Zapisano wysokość: segment [25, 4]
# Zapisano wysokość: segment [25, 5]
# Zapisano wysokość: segment [25, 6]
# Zapisano wysokość: segment [25, 7]
# Zapisano wysokość: segment [25, 8]
# Zapisano wysokość: segment [25, 9]
# Zapisano wysokość: segment [25, 10]
# Zapisano wysokość: segment [25, 11]
# Zapisano wysokość: segment [25, 12]
# Zapisano wysokość: segment [25, 13]
# Zapisano wysokość: segment [25, 14]
# Zapisano wysokość: segment [25, 15]
# Zapisano wysokość: segment [25, 16]
# Zapisano wysokość: segment [25, 17]
# Zapisano wysokość: segment [26, 0]
# Zapisano wysokość: segment [26, 1]
# Zapisano wysokość: segment [26, 2]
# Zapisano wysokość: segment [26, 3]
# Zapisano wysokość: segment [26, 4]
# Zapisano wysokość: segment [26, 5]
# Zapisano wysokość: segment [26, 6]
# Zapisano wysokość: segment [26, 7]
# Zapisano wysokość: segment [26, 8]
# Zapisano wysokość: segment [26, 9]
# Zapisano wysokość: segment [26, 10]
# Zapisano wysokość: segment [26, 11]
# Zapisano wysokość: segment [26, 12]
# Zapisano wysokość: segment [26, 13]
# Zapisano wysokość: segment [26, 14]
# Zapisano wysokość: segment [26, 15]
# Zapisano wysokość: segment [26, 16]
# Zapisano wysokość: segment [26, 17]
# Zapisano wysokość: segment [27, 0]
# Zapisano wysokość: segment [27, 1]
# Zapisano wysokość: segment [27, 2]
# Zapisano wysokość: segment [27, 3]
# Zapisano wysokość: segment [27, 4]
# Zapisano wysokość: segment [27, 5]
# Zapisano wysokość: segment [27, 6]
# Zapisano wysokość: segment [27, 7]
# Zapisano wysokość: segment [27, 8]
# Zapisano wysokość: segment [27, 9]
# Zapisano wysokość: segment [27, 10]
# Zapisano wysokość: segment [27, 11]
# Zapisano wysokość: segment [27, 12]
# Zapisano wysokość: segment [27, 13]
# Zapisano wysokość: segment [27, 14]
# Zapisano wysokość: segment [27, 15]
# Zapisano wysokość: segment [27, 16]
# Zapisano wysokość: segment [27, 17]
# Zapisano wysokość: segment [28, 0]
# Zapisano wysokość: segment [28, 1]
# Zapisano wysokość: segment [28, 2]
# Zapisano wysokość: segment [28, 3]
# Zapisano wysokość: segment [28, 4]
# Zapisano wysokość: segment [28, 5]
# Zapisano wysokość: segment [28, 6]
# Zapisano wysokość: segment [28, 7]
# Zapisano wysokość: segment [28, 8]
# Zapisano wysokość: segment [28, 9]
# Zapisano wysokość: segment [28, 10]
# Zapisano wysokość: segment [28, 11]
# Zapisano wysokość: segment [28, 12]
# Zapisano wysokość: segment [28, 13]
# Zapisano wysokość: segment [28, 14]
# Zapisano wysokość: segment [28, 15]
# Zapisano wysokość: segment [28, 16]
# Zapisano wysokość: segment [28, 17]
# Zapisano wysokość: segment [29, 0]
# Zapisano wysokość: segment [29, 1]
# Zapisano wysokość: segment [29, 2]
# Zapisano wysokość: segment [29, 3]
# Zapisano wysokość: segment [29, 4]
# Zapisano wysokość: segment [29, 5]
# Zapisano wysokość: segment [29, 6]
# Zapisano wysokość: segment [29, 7]
# Zapisano wysokość: segment [29, 8]
# Zapisano wysokość: segment [29, 9]
# Zapisano wysokość: segment [29, 10]
# Zapisano wysokość: segment [29, 11]
# Zapisano wysokość: segment [29, 12]
# Zapisano wysokość: segment [29, 13]
# Zapisano wysokość: segment [29, 14]
# Zapisano wysokość: segment [29, 15]
# Zapisano wysokość: segment [29, 16]
# Zapisano wysokość: segment [29, 17]

# %%
segment = grid_manager.read_segment(0, 0)

# %%
h, w, layers = segment.shape
print(f"Wymiary pobranego segmentu: {h}x{w}, warstwy: {layers}")
# Out:
# Wymiary pobranego segmentu: 1000x1000, warstwy: 2

# %%
mid_y, mid_x = h // 2, w // 2
road_val = segment[mid_y, mid_x, 0]    # Warstwa 0: Drogi
altitude_val = segment[mid_y, mid_x, 1] # Warstwa 1: Wysokość

# %%
print(f"\nPrzykładowy punkt [{mid_y}, {mid_x}]:")
print(f"  -> Czy jest drogą (0/1): {road_val}")
print(f"  -> Wysokość (Z): {altitude_val}")
# Out:
# Przykładowy punkt [500, 500]:
#   -> Czy jest drogą (0/1): 0.0
#   -> Wysokość (Z): 174.39186096191406

# %%
min_h = np.min(segment[:, :, 1])
max_h = np.max(segment[:, :, 1])
mean_h = np.mean(segment[:, :, 1])

# %%
print(f"\nStatystyki wysokości w segmencie:")
print(f"  -> Min: {min_h}")
print(f"  -> Max: {max_h}")
print(f"  -> Średnia: {mean_h}")
# Out:
# Statystyki wysokości w segmencie:
#   -> Min: 160.00001525878906
#   -> Max: 239.99998474121094
#   -> Średnia: 201.21461486816406
